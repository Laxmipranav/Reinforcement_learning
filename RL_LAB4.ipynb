# %% [markdown]
# <a href="https://colab.research.google.com/github/Laxmipranav/Reinforcement_learning/blob/main/RL_LAB4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math


machines = ['A', 'B', 'C']

N = {
    'A': 0,
    'B': 0,
    'C': 0
}

R = {
    'A': 0,
    'B': 0,
    'C': 0
}

Q = {
    'A': 0.0,
    'B': 0.0,
    'C': 0.0
}

UCB = {
    'A': 0.0,
    'B': 0.0,
    'C': 0.0
}

N_play = 10

total_reward = 0



for play in range(1, N_play + 1):

    print("\n-----------------------------")
    print("Play:", play)
    print("-----------------------------")


    for machine in machines:

        # Make sure every machine is played at least once
        if N[machine] == 0:
            UCB[machine] = float('inf')
        else:
            UCB[machine] = Q[machine] + math.sqrt(
                (2 * math.log(play)) / N[machine]
            )

    selected_machine = max(machines, key=lambda x: UCB[x])

    print("Selected Machine:", selected_machine)




    reward = float(
        input("Enter reward obtained from machine "
              + selected_machine + ": ")
    )

    N[selected_machine] += 1

    R[selected_machine] += reward

    # Incremental sample-average formula
    Q[selected_machine] = Q[selected_machine] + (
        reward - Q[selected_machine]
    ) / N[selected_machine]

    total_reward += reward


    print("\nCurrent Values:")

    for machine in machines:
        print(
            machine,
            "N =", N[machine],
            "R =", R[machine],
            "Q =", round(Q[machine], 3),
            "UCB =", round(UCB[machine], 3)
            if UCB[machine] != float('inf')
            else "INF"
        )



print("\n\n====================================")
print("FINAL RESULTS")
print("====================================")

print("\nMachine\tN\tR\tQ-value\tUCB")


for machine in machines:

    if N[machine] == 0:
        UCB[machine] = float('inf')
    else:
        UCB[machine] = Q[machine] + math.sqrt(
            (2 * math.log(N_play)) / N[machine]
        )

    print(
        machine,
        "\t",
        N[machine],
        "\t",
        R[machine],
        "\t",
        round(Q[machine], 3),
        "\t",
        round(UCB[machine], 3)
        if UCB[machine] != float('inf')
        else "INF"
    )

print("\nTotal Reward =", total_reward)

# Best machine
best_machine = max(machines, key=lambda x: Q[x])

print("Best Machine =", best_machine)
print("Best Q-value =", round(Q[best_machine], 3))
# Out:
# -----------------------------
# Play: 1
# -----------------------------
# Selected Machine: A
# Enter reward obtained from machine A: 2
#
# Current Values:
# A N = 1 R = 2.0 Q = 2.0 UCB = INF
# B N = 0 R = 0 Q = 0.0 UCB = INF
# C N = 0 R = 0 Q = 0.0 UCB = INF
#
# -----------------------------
# Play: 2
# -----------------------------
# Selected Machine: B
# Enter reward obtained from machine B: 3
#
# Current Values:
# A N = 1 R = 2.0 Q = 2.0 UCB = 3.177
# B N = 1 R = 3.0 Q = 3.0 UCB = INF
# C N = 0 R = 0 Q = 0.0 UCB = INF
#
# -----------------------------
# Play: 3
# -----------------------------
# Selected Machine: C
# Enter reward obtained from machine C: 4
#
# Current Values:
# A N = 1 R = 2.0 Q = 2.0 UCB = 3.482
# B N = 1 R = 3.0 Q = 3.0 UCB = 4.482
# C N = 1 R = 4.0 Q = 4.0 UCB = INF
#
# -----------------------------
# Play: 4
# -----------------------------
# Selected Machine: C
# Enter reward obtained from machine C: 4
#
# Current Values:
# A N = 1 R = 2.0 Q = 2.0 UCB = 3.665
# B N = 1 R = 3.0 Q = 3.0 UCB = 4.665
# C N = 2 R = 8.0 Q = 4.0 UCB = 5.665
#
# -----------------------------
# Play: 5
# -----------------------------
# Selected Machine: C
# Enter reward obtained from machine C: 3
#
# Current Values:
# A N = 1 R = 2.0 Q = 2.0 UCB = 3.794
# B N = 1 R = 3.0 Q = 3.0 UCB = 4.794
# C N = 3 R = 11.0 Q = 3.667 UCB = 5.269
#
# -----------------------------
# Play: 6
# -----------------------------
# Selected Machine: B
# Enter reward obtained from machine B: 2
#
# Current Values:
# A N = 1 R = 2.0 Q = 2.0 UCB = 3.893
# B N = 2 R = 5.0 Q = 2.5 UCB = 4.893
# C N = 3 R = 11.0 Q = 3.667 UCB = 4.76
#
# -----------------------------
# Play: 7
# -----------------------------
# Selected Machine: C
# Enter reward obtained from machine C: 3
#
# Current Values:
# A N = 1 R = 2.0 Q = 2.0 UCB = 3.973
# B N = 2 R = 5.0 Q = 2.5 UCB = 3.895
# C N = 4 R = 14.0 Q = 3.5 UCB = 4.806
#
# -----------------------------
# Play: 8
# -----------------------------
# Selected Machine: C
# Enter reward obtained from machine C: 4
#
# Current Values:
# A N = 1 R = 2.0 Q = 2.0 UCB = 4.039
# B N = 2 R = 5.0 Q = 2.5 UCB = 3.942
# C N = 5 R = 18.0 Q = 3.6 UCB = 4.52
#
# -----------------------------
# Play: 9
# -----------------------------
# Selected Machine: C
# Enter reward obtained from machine C: 1
#
# Current Values:
# A N = 1 R = 2.0 Q = 2.0 UCB = 4.096
# B N = 2 R = 5.0 Q = 2.5 UCB = 3.982
# C N = 6 R = 19.0 Q = 3.167 UCB = 4.537
#
# -----------------------------
# Play: 10
# -----------------------------
# Selected Machine: A
# Enter reward obtained from machine A: 6
#
# Current Values:
# A N = 2 R = 8.0 Q = 4.0 UCB = 4.146
# B N = 2 R = 5.0 Q = 2.5 UCB = 4.017
# C N = 6 R = 19.0 Q = 3.167 UCB = 4.043
#
#
# ====================================
# FINAL RESULTS
# ====================================
#
# Machine	N	R	Q-value	UCB
# A 	 2 	 8.0 	 4.0 	 5.517
# B 	 2 	 5.0 	 2.5 	 4.017
# C 	 6 	 19.0 	 3.167 	 4.043
#
# Total Reward = 32.0
# Best Machine = A
# Best Q-value = 4.0
